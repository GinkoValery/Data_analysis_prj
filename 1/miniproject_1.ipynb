# %% [markdown]
# # Минипроект: данные о бронированиях

# %%
import pandas as pd

# %%
# Import data from local PC
df = pd.read_csv("2_bookings.csv",sep = ";")
df.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
df.shape
# Out:
# (119390, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Hotel                      119390 non-null  object
#  1   Is Canceled                119390 non-null  int64
#  2   Lead Time                  119390 non-null  int64
#  3   arrival full date          119390 non-null  object
#  4   Arrival Date Year          119390 non-null  int64
#  5   Arrival Date Month         119390 non-null  object
#  6   Arrival Date Week Number   119390 non-null  int64
#  7   Arrival Date Day of Month  119390 non-null  int64
#  8   Stays in Weekend nights    119390 non-null  int64
#  9   Stays in week nights       119390 non-null  int64
#  10  stays total nights         119390 non-null  int64
#  11  Adults                     119390 non-null  int64
#  12  Children                   119386 non-null  float64
# ...

# %%
# Work with column names: change to lower case and remove spaces
df.columns = list(map(lambda x: x.replace(" ", "_").lower(), df.columns))
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %% [markdown]
# # 3. Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5.

# %%
df[df.is_canceled == 0] \
    .groupby("country", as_index = False).is_canceled.count() \
    .rename(columns = {"is_canceled":"num_bookings"}) \
    .sort_values(by = "num_bookings", ascending = False) \
    .head(5)
# Out:
#     country  num_bookings
# 125     PRT         21071
# 57      GBR          9676
# 54      FRA          8481
# 50      ESP          6391
# 42      DEU          6069

# %% [markdown]
# # 4. На сколько ночей в среднем бронируют отели разных типов?

# %%
df.hotel.value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df \
    .groupby("hotel", as_index = False).stays_total_nights.mean() \
    .rename(columns = {"stays_total_nights":"avg_stays_total_nights"}) \
    .sort_values(by = "avg_stays_total_nights", ascending = False)
# Out:
#           hotel  avg_stays_total_nights
# 1  Resort Hotel                4.318547
# 0    City Hotel                2.978142

# %% [markdown]
# # 5. Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете?

# %%
len(df.query("reserved_room_type != assigned_room_type"))
# Out:
# 14917

# %% [markdown]
# # 6. Проанализируйте даты запланированного прибытия.
# ## – На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?

# %%
df_y_mnth = df[df.is_canceled == 0] \
    .groupby([ 'arrival_date_year', 'arrival_date_month'], as_index = False).hotel.count() \
    .rename(columns = {"hotel":"num_bookings"}) \
    .sort_values(by = "num_bookings", ascending = False)
df_y_mnth.head()
# Out:
#     arrival_date_year arrival_date_month  num_bookings
# 16               2016            October          3689
# 14               2016                May          3563
# 25               2017                May          3551
# 17               2016          September          3372
# 6                2016              April          3367

# %%
df_y_mnth[df_y_mnth.arrival_date_year == 2016].head(1)
# Out:
#     arrival_date_year arrival_date_month  num_bookings
# 16               2016            October          3689

# %%
df_y_mnth[df_y_mnth.arrival_date_year == 2017].head(1)
# Out:
#     arrival_date_year arrival_date_month  num_bookings
# 25               2017                May          3551

# %% [markdown]
# ## – Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов

# %%
df1 = df[(df.is_canceled == 1) & (df.hotel == 'City Hotel')] \
    .groupby([ 'arrival_date_year', 'arrival_date_month'], as_index = False).is_canceled.count() \
    .sort_values(by = [ "arrival_date_year", "is_canceled"], ascending = [True, False]) 
df1
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 5                2015          September         1543
# 4                2015            October         1321
# 0                2015             August         1232
# 2                2015               July          939
# 1                2015           December          668
# 3                2015           November          301
# 16               2016            October         1947
# 12               2016               June         1720
# 17               2016          September         1567
# 6                2016              April         1539
# 14               2016                May         1436
# 15               2016           November         1360
# 7                2016             August         1247
# 13               2016              March         1108
# 8                2016           December         1072
# 11               2016               July         1043
# ...

# %%
 
df1['rnk'] = df1.groupby('arrival_date_year').is_canceled.rank(ascending = False)
df1.query("rnk == 1").drop(columns = ["rnk"])
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 5                2015          September         1543
# 16               2016            October         1947
# 25               2017                May         2217

# %% [markdown]
# # 7.	Посмотрите на числовые характеристики трёх переменных: adults, children и babies. Какая из них имеет наибольшее среднее значение?

# %%
df[['adults', 'children', 'babies']].describe()
# Out:
#               adults       children         babies
# count  119390.000000  119386.000000  119390.000000
# mean        1.856403       0.103890       0.007949
# std         0.579261       0.398561       0.097436
# min         0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         2.000000       0.000000       0.000000
# max        55.000000      10.000000      10.000000

# %% [markdown]
# # 8. Создайте колонку total_kids, объединив children и babies. Для отелей какого типа среднее значение переменной оказалось наибольшим?

# %%
df["total_kids"] = df["children"] + df["babies"]

# %%
df.groupby("hotel", as_index = False)["total_kids"].mean()
# Out:
#           hotel  total_kids
# 0    City Hotel    0.096311
# 1  Resort Hotel    0.142586

# %% [markdown]
# # 9. Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), в противном случае – False. Посчитайте отношение количества ушедших пользователей к общему количеству клиентов, выраженное в процентах (churn rate). Укажите, среди какой группы показатель выше

# %%
df["has_kids"] = df["total_kids"] > 0
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.total_kids.apply(lambda x: (x > 0)*1)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: total_kids, Length: 119390, dtype: int64

# %%
df.total_kids.apply(lambda x: 1 if (x > 0) else 0)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: total_kids, Length: 119390, dtype: int64

# %%
df_CR = df.groupby(["has_kids", "is_canceled"], as_index = False)["reservation_status"].count()

df_CR["all_cust"] = df_CR.groupby( "has_kids")["reservation_status"].transform(sum)
df_CR["churn_rate"] = df_CR.reservation_status/df_CR.all_cust
df_CR.query("is_canceled == 1")
# Out:
#    has_kids  is_canceled  reservation_status  all_cust  churn_rate
# 1     False            1               40965    110058    0.372213
# 3      True            1                3259      9332    0.349228

# %%
df[df.has_kids == True].is_canceled.count()
# Out:
# 9332

# %%
df[df.has_kids == False].is_canceled.count()
# Out:
# 110058
